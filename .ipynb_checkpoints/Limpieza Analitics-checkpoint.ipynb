# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from datascience import *

# %%
# !ls *ipynb
# Out:
# 'Amadeus + Detalle Busquedas 27MAY - 02JUN.ipynb'
# 'Analisis busquedas Abril.ipynb'
# 'Analisis CD vuelos producto paquetes cupos.ipynb'
# 'Busquedas Diarias.ipynb'
# 'Limpieza Analitics.ipynb'
# 'Prueba Correlación de Pearson.ipynb'
# 'sed cut tr python.ipynb'
#  Untitled1.ipynb
#  Untitled.ipynb

# %%
# !pwd
# Out:
# /run/media/marco/CAC5-0DAB/Bash_data_analytics

# %%
from datascience import *
import numpy as np

# %%
# !ls /run/media/marco/CAC5-0DAB/*csv
# Out:
# /run/media/marco/CAC5-0DAB/limpios.csv

# %%
! cat /run/media/marco/CAC5-0DAB/limpios.csv
# Out:
# turismoraysspa,hoteles,resultados,1537,0,cancuncosta-mujeres-mexico,16-02-2021,27-02-2021,h1
# calipsoviajes,hoteles,resultados,6386,0,new-york-nueva-york-estados-unidos,17-08-2021,22-08-2021,h1
# grupomas,hoteles,resultados,7200,0,playa-del-carmenriviera-maya-mexico,17-02-2021,26-02-2021,h1
# travelwise,hoteles,resultados,9486,0,tulum-mexico,21-01-2021,25-01-2021,h1
# turismoraysspa,hoteles,resultados,4927,0,las-vegas-estados-unidos,06-06-2021,07-06-2021,h1
# austerdmc,hoteles,resultados,5796,0,miami-fl-estados-unidos,21-03-2021,30-03-2021,h1
# argentur,hoteles,resultados,1537,0,cancuncosta-mujeres-mexico,23-07-2021,30-07-2021,h1
# lifetrip,hoteles,resultados,7493,0,punta-cana-republica-dominicana,02-02-2021,10-02-2021,h1
# onetrip,hoteles,resultados,1537,0,cancuncosta-mujeres-mexico,08-12-2021,15-12-2021,h1
# lifetrip,hoteles,resultados,7200,0,playa-del-carmenriviera-maya-mexico,08-06-2021,16-06-2021,h1
# ...

# %%
df=pd.read_csv('/run/media/marco/CAC5-0DAB/limpios.csv',)
df.head()
# Out:
#    turismoraysspa  hoteles  resultados  1537  0  \
# 0   calipsoviajes  hoteles  resultados  6386  0
# 1        grupomas  hoteles  resultados  7200  0
# 2      travelwise  hoteles  resultados  9486  0
# 3  turismoraysspa  hoteles  resultados  4927  0
# 4       austerdmc  hoteles  resultados  5796  0
#
#             cancuncosta-mujeres-mexico  16-02-2021  27-02-2021  h1
# 0   new-york-nueva-york-estados-unidos  17-08-2021  22-08-2021  h1
# 1  playa-del-carmenriviera-maya-mexico  17-02-2021  26-02-2021  h1
# 2                         tulum-mexico  21-01-2021  25-01-2021  h1
# 3             las-vegas-estados-unidos  06-06-2021  07-06-2021  h1
# 4              miami-fl-estados-unidos  21-03-2021  30-03-2021  h1

# %%
df.columns=['Agencia','Vertical','resul','nro','cero','Destino','in','out','otro']

# %%
df
# Out:
#              Agencia Vertical       resul   nro cero  \
# 0      calipsoviajes  hoteles  resultados  6386    0
# 1           grupomas  hoteles  resultados  7200    0
# 2         travelwise  hoteles  resultados  9486    0
# 3     turismoraysspa  hoteles  resultados  4927    0
# 4          austerdmc  hoteles  resultados  5796    0
# ...              ...      ...         ...   ...  ...
# 3322     zonahoraria   vuelos  resultados   EZE  GIG
# 3323     zonahoraria   vuelos  resultados   EZE  GIG
# 3324     zonahoraria   vuelos  resultados   SLA  CUN
# 3325     zonahoraria   vuelos  resultados   SLA  CUN
# 3326     zonahoraria   vuelos  resultados   SLA  CUN
#
#                                   Destino          in         out       otro
# 0      new-york-nueva-york-estados-unidos  17-08-2021  22-08-2021         h1
# 1     playa-del-carmenriviera-maya-mexico  17-02-2021  26-02-2021         h1
# 2                            tulum-mexico  21-01-2021  25-01-2021         h1
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              Agencia Vertical       resul   nro cero  \
# 0      calipsoviajes  hoteles  resultados  6386    0
# 1           grupomas  hoteles  resultados  7200    0
# 2         travelwise  hoteles  resultados  9486    0
# 3     turismoraysspa  hoteles  resultados  4927    0
# 4          austerdmc  hoteles  resultados  5796    0
# ...              ...      ...         ...   ...  ...
# 3322     zonahoraria   vuelos  resultados   EZE  GIG
# 3323     zonahoraria   vuelos  resultados   EZE  GIG
# 3324     zonahoraria   vuelos  resultados   SLA  CUN
# 3325     zonahoraria   vuelos  resultados   SLA  CUN
# 3326     zonahoraria   vuelos  resultados   SLA  CUN
#
#                                   Destino          in         out       otro
# 0      new-york-nueva-york-estados-unidos  17-08-2021  22-08-2021         h1
# 1     playa-del-carmenriviera-maya-mexico  17-02-2021  26-02-2021         h1
# ...

# %%
df?

# %%
datascience?
# Out:
# Object `datascience` not found.

# %%
agencias=pd.DataFrame(df)

# %%
agencias.groupby('Vertical').tail(30)
# Out:
#                              Agencia  Vertical       resul            nro  \
# 738   4rumbosbylatinoamericaincoming  paquetes     detalle          43572
# 917                aterrizandosuenos  paquetes     detalle          43587
# 918                aterrizandosuenos  paquetes     detalle          43587
# 1588                         galfras     cupos  resultados  ciudad_origen
# 1589                         galfras     cupos  resultados  ciudad_origen
# ...                              ...       ...         ...            ...
# 3322                     zonahoraria    vuelos  resultados            EZE
# 3323                     zonahoraria    vuelos  resultados            EZE
# 3324                     zonahoraria    vuelos  resultados            SLA
# 3325                     zonahoraria    vuelos  resultados            SLA
# 3326                     zonahoraria    vuelos  resultados            SLA
#
#                                 cero           Destino                  in  \
# ...

# %%
agencias.describe()
# Out:
#                 Agencia Vertical       resul   nro  cero  \
# count              3324     3327        3327  3327  3327
# unique              300        6           3   253   204
# top     siddarthaviajes   vuelos  resultados   BUE     0
# freq                218     1542        3044   880  1497
#
#                                     Destino         in      out  otro
# count                                  3327       3230     3327  3327
# unique                                  398        378      367    61
# top     playa-del-carmenriviera-maya-mexico  productos  adultos    h1
# freq                                    307        100     1437  1497

# %%
agencias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3327 entries, 0 to 3326
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Agencia   3324 non-null   object
#  1   Vertical  3327 non-null   object
#  2   resul     3327 non-null   object
#  3   nro       3327 non-null   object
#  4   cero      3327 non-null   object
#  5   Destino   3327 non-null   object
#  6   in        3230 non-null   object
#  7   out       3327 non-null   object
#  8   otro      3327 non-null   object
# dtypes: object(9)
# memory usage: 234.1+ KB

# %%
agencias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3327 entries, 0 to 3326
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Agencia   3324 non-null   object
#  1   Vertical  3327 non-null   object
#  2   resul     3327 non-null   object
#  3   nro       3327 non-null   object
#  4   cero      3327 non-null   object
#  5   Destino   3327 non-null   object
#  6   in        3230 non-null   object
#  7   out       3327 non-null   object
#  8   otro      3327 non-null   object
# dtypes: object(9)
# memory usage: 234.1+ KB

# %%
agencias['Agencia'].describe().notnull()
# Out:
# count     True
# unique    True
# top       True
# freq      True
# Name: Agencia, dtype: bool

# %%
vuelos = agencias[agencias['Vertical'] == 'vuelos']

# %%
vuelos
# Out:
#                                       Agencia Vertical       resul  nro cero  \
# 67                    algarroboviajesyturismo   vuelos  resultados  BUE  MAD
# 71                                ceiboviajes   vuelos  resultados  BUE  USH
# 89    sofiaevelynhernandoturismointernacional   vuelos  resultados  BUE  CUN
# 92                                        adn   vuelos  resultados  EZE  MCO
# 104                               ceiboviajes   vuelos  resultados  BUE  PUJ
# ...                                       ...      ...         ...  ...  ...
# 3322                              zonahoraria   vuelos  resultados  EZE  GIG
# 3323                              zonahoraria   vuelos  resultados  EZE  GIG
# 3324                              zonahoraria   vuelos  resultados  SLA  CUN
# 3325                              zonahoraria   vuelos  resultados  SLA  CUN
# 3326                              zonahoraria   vuelos  resultados  SLA  CUN
#
# ...

# %%
paquetes = agencias[agencias['Vertical'] == 'paquetes']

# %%
hoteles = agencias[agencias['Vertical'] == 'hoteles']

# %%
hoteles.groupby('Agencia').sum()[['Destino','in']]
# Out:
#                                                              Destino  \
# Agencia
# KaizenViajes       mar-de-ajo-argentinamar-del-plata-argentinamir...
# abracadabraviajes                                  ushuaia-argentina
# adsmundo           miami-fl-estados-unidosplaya-del-carmenriviera...
# agapeturismo       punta-cana-republica-dominicanamexico-city-mex...
# aitanaviajes                         punta-cana-republica-dominicana
# ...                                                              ...
# yolandaliveratour  las-vegas-estados-unidosnew-york-nueva-york-es...
# yularaviajes       playa-del-carmenriviera-maya-mexicocancuncosta...
# zanellatoviajes                      punta-cana-republica-dominicana
# zeruanviajes       imbassai-brasilflorianopolis-brasilflorianopol...
# zonadepartida                   iguazu-argentinafoz-de-iguazu-brasil
#
#                                                                   in
# Agencia
# ...

# %%
paquetes.head(30)
# Out:
#                              Agencia  Vertical    resul    nro  \
# 738   4rumbosbylatinoamericaincoming  paquetes  detalle  43572
# 917                aterrizandosuenos  paquetes  detalle  43587
# 918                aterrizandosuenos  paquetes  detalle  43587
# 1728             himalayalasvarillas  paquetes  detalle  43587
# 1729             himalayalasvarillas  paquetes  detalle  43587
# 1922                        lajuntur  paquetes  detalle  43587
#
#                                 cero     Destino  \
# 738   tesoros-de-turquia-01-de-abril           1
# 917   tesoros-de-turquia-17-de-junio           1
# 918   tesoros-de-turquia-17-de-junio  resultados
# 1728  tesoros-de-turquia-17-de-junio       token
# 1729  tesoros-de-turquia-17-de-junio  resultados
# 1922  tesoros-de-turquia-17-de-junio           1
#
#                                         in           out           otro
# 738                                      1      00:00:00              0
# ...

# %%
vuelos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1542 entries, 67 to 3326
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Agencia   1542 non-null   object
#  1   Vertical  1542 non-null   object
#  2   resul     1542 non-null   object
#  3   nro       1542 non-null   object
#  4   cero      1542 non-null   object
#  5   Destino   1542 non-null   object
#  6   in        1445 non-null   object
#  7   out       1542 non-null   object
#  8   otro      1542 non-null   object
# dtypes: object(9)
# memory usage: 120.5+ KB

# %%
vuelos.describe()
# Out:
#                 Agencia Vertical       resul   nro  cero     Destino  \
# count              1542     1542        1542  1542  1542        1542
# unique              144        1           1    29   111         254
# top     siddarthaviajes   vuelos  resultados   BUE   CUN  10-02-2021
# freq                176     1542        1542   880   286          41
#
#                 in      out              otro
# count         1445     1542              1542
# unique         260       44                57
# top     21-02-2021  adultos  1&includeBaggage
# freq            37     1437               358

# %%
vuelos.groupby('Agencia').sum()[['nro','cero']]
# Out:
#                                                 nro  \
# Agencia
# ENTREMARES                                   BUEBUE
# KaizenViajes                        BUEBUEBUEBUEBUE
# RAGVI                                        BUEBUE
# abbruzzeselozadaviajes                    BUEBUEBUE
# adn                              EZEEZEEZEJUJJUJSLA
# ...                                             ...
# willyfogturismo                     CORBUEBUECORCOR
# wowviajesyturismo                         BUESCLSCL
# yoviajoevt                                      NQN
# zoluviajes                                      BUE
# zonahoraria             CORSLACORCOREZEEZESLASLASLA
#
#                                                cero
# Agencia
# ENTREMARES                                   LAXLAX
# KaizenViajes                        USHUSHUSHUSHUSH
# RAGVI                                        CUNCUN
# abbruzzeselozadaviajes                    BPSCTGNAT
# adn                              MCOMCOMCOAEPEzeEZE
# ...

# %%
vuelos.groupby('cero').sum()['Agencia']
# Out:
# cero
# ADZ    ceiboviajesceiboviajesceiboviajesmarielalonnet...
# AEP                                                  adn
# AFA    dipviajesbalcarceviajesbalcarceviajesbalcarcev...
# AGP    gabrielapistekmooreatravelmooreatravelmooreatr...
# ALC                               atueltravelatueltravel
#                              ...
# USH    ceiboviajesasocmutual9dejuliofreyreclaseturist...
# VDM                       siddarthaviajessiddarthaviajes
# VER             gerenciadeviajesevytgerenciadeviajesevyt
# YMQ                                       collagecollage
# ZAG                           flysoonviajesflysoonviajes
# Name: Agencia, Length: 111, dtype: object

# %%
vuelos['Agencia'].value_counts().head(20)
# Out:
# siddarthaviajes                            176
# dipviajes                                  131
# himalayarioiv                               87
# ceiboviajes                                 71
# pymviajes                                   65
# restecoperadormayorista                     57
# mcgviajesyturismo                           53
# onetripcarlospaz                            44
# serviciosaerocomercialessanluis             37
# mondeviajes                                 37
# asocmutual9dejuliofreyre                    36
# jpribentoviajesyturismo                     32
# sofiaevelynhernandoturismointernacional     30
# lifetrip                                    29
# dubaiviajesgralpaz                          26
# melisamunoz                                 22
# gollua                                      21
# marielalonneturismo                         21
# turismoestaciondelsol                       20
# collage                                     18
# ...

# %%
paquetes['cero'].value_counts().head(20)
# Out:
# tesoros-de-turquia-17-de-junio    5
# tesoros-de-turquia-01-de-abril    1
# Name: cero, dtype: int64

# %%
vuelos['cero'].value_counts().head(20)
# Out:
# CUN    286
# PUJ    183
# BUE     75
# MDQ     69
# BRC     67
# FTE     62
# HAV     50
# IGR     50
# MDZ     45
# SLA     43
# RIO     36
# USH     35
# MIA     33
# CTG     27
# REC     26
# MAD     23
# MBJ     23
# COR     16
# SDQ     15
# NYC     15
# Name: cero, dtype: int64

# %%
vuelos['cero'].value_counts().head(20)
# Out:
# CUN    286
# PUJ    183
# BUE     75
# MDQ     69
# BRC     67
# FTE     62
# HAV     50
# IGR     50
# MDZ     45
# SLA     43
# RIO     36
# USH     35
# MIA     33
# CTG     27
# REC     26
# MAD     23
# MBJ     23
# COR     16
# SDQ     15
# NYC     15
# Name: cero, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
vuelos['cero'].value_counts().head()
# Out:
# CUN    286
# PUJ    183
# BUE     75
# MDQ     69
# BRC     67
# Name: cero, dtype: int64

# %%
# !pwd
# Out:
# /run/media/marco/CAC5-0DAB/Bash_data_analytics
