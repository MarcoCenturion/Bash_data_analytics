# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
website = 'https://www.aa2000.com.ar/cordoba'

# %%
respuesta = requests.get(website)

# %%
print(respuesta)
# Out:
# <Response [200]>

# %%
type(respuesta)
# Out:
# requests.models.Response

# %%
contenido = respuesta.text

# %%
soup = BeautifulSoup(contenido, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- HTML5 Boilerplate -->
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if IE 9]>         <html class="no-js ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js">
#  <!--<![endif]-->
#  <head id="Head1">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Vuelos - Córdoba - Aeropuertos Argentina 2000
#   </title>
#   <meta content="Aeropuertos Argentina 2000" name="description"/>
#   <meta content="Aeropuertos, Argentina, Aerolineas" name="keywords"/>
#   <meta content="www.aa2000.com.ar" name="author"/>
#   <meta content="on" http-equiv="cleartype"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
# ...

# %%
print(soup.title)
# Out:
# <title>
# 	Vuelos - Córdoba - Aeropuertos Argentina 2000
# </title>

# %%
vuelos = soup.find('td', class_='td.vuelo')

# %%
tabla = soup.find_all('td', class_=['linea','vuelo','status'])

# %%
tabla
# Out:
# [<td class="vuelo">AR 1523</td>,
#  <td class="linea">
#  <img class="logoAero" onerror="this.onerror=null;this.src='/img/generic_grilla_arribos.GIF';" src="https://www.aa2000.com.ar/img/aerolineas/AR_200.GIF"/><span>Aerolineas Argentinas</span></td>,
#  <td class="status">
#  <div class="statusText" style="background-color: #008000">Aterrizado (10:09)</div>
#  </td>,
#  <td class="vuelo">AR 1500</td>,
#  <td class="linea">
#  <img class="logoAero" onerror="this.onerror=null;this.src='/img/generic_grilla_arribos.GIF';" src="https://www.aa2000.com.ar/img/aerolineas/AR_200.GIF"/><span>Aerolineas Argentinas</span></td>,
#  <td class="status">
#  <div class="statusText" style="background-color: #008000">Aterrizado (11:25)</div>
#  </td>,
#  <td class="vuelo">AR 1507</td>,
#  <td class="linea">
#  <img class="logoAero" onerror="this.onerror=null;this.src='/img/generic_grilla_arribos.GIF';" src="https://www.aa2000.com.ar/img/aerolineas/AR_200.GIF"/><span>Aerolineas Argentinas</span></td>,
# ...

# %%
# Out:
# <!DOCTYPE html>
# <!-- HTML5 Boilerplate --><!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]--><!--[if IE 9]>         <html class="no-js ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js">
# <!--<![endif]-->
# <head id="Head1"><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>
# 	Vuelos - Córdoba - Aeropuertos Argentina 2000
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 155.1 kB/s eta 0:00:00m eta 0:00:010:00:03
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 KB 163.3 kB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 174.7 kB/s eta 0:00:00m eta 0:00:010:00:03
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/marco/scrapping/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
tabla2 = pd.read_html(website)

# %%
tabla2
# Out:
# [       Horario       Vuelo Linea Aerea      Origen                  Estima  \
#  0   25/03/2022  25/03/2022  25/03/2022  25/03/2022              25/03/2022
#  1        10:20         NaN       10:09     AR 1523   Aerolineas Argentinas
#  2        11:30         NaN       11:25     AR 1500   Aerolineas Argentinas
#  3        11:50         NaN       11:39     AR 1507   Aerolineas Argentinas
#  4        12:15       12:44       12:45     AR 1508   Aerolineas Argentinas
#  5        14:20         NaN       14:11     AR 1502   Aerolineas Argentinas
#  6        14:55         NaN       14:39     AR 1535   Aerolineas Argentinas
#  7        15:05         NaN       14:57     FO 5471   Flybondi Lineas Areas
#  8        15:23         NaN       15:10     WJ 3266  Jetsmart Airlines S.a.
#  9        16:30       16:25       16:15     AR 1515   Aerolineas Argentinas
#  10       17:30         NaN       17:01     AR 1517   Aerolineas Argentinas
# ...

# %%
data=pd.DataFrame(tabla2)
# Out:
# /home/marco/scrapping/lib/python3.10/site-packages/pandas/core/internals/construction.py:576: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
data
# Out:
#                                                    0
# 0         Horario       Vuelo Linea Aerea      Or...
# 1         Horario       Vuelo Linea Aerea     Des...
